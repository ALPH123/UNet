# %%
import sys
sys.path.append('/home/hwang/anaconda3/lib/python3.7/site-packages/')

from sklearn import datasets
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras as keras 
import numpy as np
import matplotlib.pyplot as plt
import os
import SimpleITK as sitk
import math

from keras.utils.np_utils import to_categorical
from tensorflow.keras import optimizers 
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, MaxPooling2D, Dropout, Input, Lambda, Reshape, AveragePooling2D, BatchNormalization
from keras.layers.merge import add, concatenate
from tensorflow.keras.applications.resnet50 import ResNet50, decode_predictions

from tensorflow.keras import backend as K
from tensorflow.keras.utils import plot_model

from tensorflow.keras.callbacks import ModelCheckpoint 
from tensorflow.keras.callbacks import EarlyStopping, LambdaCallback
from tensorflow.keras import optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.layers.normalization import BatchNormalization

from keras_unet.utils import plot_imgs, get_augmented, plot_segm_history
from keras_unet.metrics import iou, iou_thresholded
from keras_unet.losses import jaccard_distance 
from keras_unet.models import custom_unet

from utils import *
# from callbacks import call
import configTrain
from network import unet3d
from tensorflow.keras.optimizers import Adam

os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

# %%
tf.__version__

import tensorflow.compat.v1 as tf

# %%
# delete .DS_Store file in each folder 

# resample
            
resampath =  '/Users/eo-jin/Documents/research/1_MM/Segmentation_UNet/T1NORM/TRAIN_3D/'
# resampath = '/Users/hwang/Documents/research/2_Prostate/Unet/roi_T2/Tz_resamp/train/'

resampfile = os.listdir(resampath)
resampfile.sort()
num_seg = len(resampfile)
count_seg = 0
for item_resamp in os.listdir(resampath):
    current_resamp = os.path.basename(item_resamp)
    if current_resamp == '.DS_Store':
        fullpath = os.path.join(resampath,current_resamp)
        os.remove(fullpath)

# %%
# feature for deep learning (3D): img

resampath = '/Users/eo-jin/Documents/research/1_MM/Segmentation_UNet/T1NORM/TRAIN_3D/'
# resampath = '/Users/hwang/Documents/research/2_Prostate/Unet/nT2/Tz_resamp/train/'

resampfile = os.listdir(resampath)
resampfile.sort()
num_img = len(resampfile)

first = sitk.ReadImage(os.path.join(resampath,resampfile[0]))
feature = sitk.GetArrayFromImage(first)
feature_temp = feature.transpose(1,2,0)
feature_reshape = feature_temp.reshape(feature_temp.shape[0], feature_temp.shape[1], feature_temp.shape[2], 1)

num = 1

for n in os.listdir(resampath):

    i = sitk.ReadImage(os.path.join(resampath,resampfile[num]))
    j = sitk.GetArrayFromImage(i)
    j_temp = j.transpose(1,2,0)
    j_reshape = j_temp.reshape(j_temp.shape[0], j_temp.shape[1], j_temp.shape[2], 1)

    feature_reshape = np.concatenate([feature_reshape,j_reshape], axis = 3)
    
feature_reshape = feature_reshape[:,:,:,0:10]

# %%
# feature for deep learning (3D): mask 

resampath = '/Users/eo-jin/Documents/research/1_MM/Segmentation_UNet/ROI_RAD/TRAIN_3D/'
# resampath = '/Users/hwang/Documents/research/2_Prostate/Unet/nT2/Tz_resamp/train/'

resampfile = os.listdir(resampath)
resampfile.sort()
num_img = len(resampfile)

first = sitk.ReadImage(os.path.join(resampath,resampfile[0]))
mask = sitk.GetArrayFromImage(first)
mask_temp = mask.transpose(1,2,0)
mask_reshape = mask_temp.reshape(mask_temp.shape[0], mask_temp.shape[1], mask_temp.shape[2], 1)

num = 1

for n in os.listdir(resampath):

    i = sitk.ReadImage(os.path.join(resampath,resampfile[num]))
    j = sitk.GetArrayFromImage(i)
    j_temp = j.transpose(1,2,0)
    j_reshape = j_temp.reshape(j_temp.shape[0], j_temp.shape[1], j_temp.shape[2], 1)

    mask_reshape = np.concatenate([feature_reshape,j_reshape], axis = 3)
    
mask_reshape = mask_reshape[:,:,:,0:10]

# %%
# feature normalization: 0-1

maxval = np.amax(feature)
feature_norm = feature_reshape/maxval

# %%
feature_reshape.shape
mask_reshape.shape
# Out:
# (528, 528, 19, 10)

# %%
x_train = feature_reshape
y_train = mask_reshape

# %%
# delete .DS_Store file in each folder 

# resample
            
resampath =  '/Users/eo-jin/Documents/research/1_MM/Segmentation_UNet/T1NORM/TEST/'
# resampath = '/Users/hwang/Documents/research/2_Prostate/Unet/roi_T2/Tz_resamp/train/'

resampfile = os.listdir(resampath)
resampfile.sort()
num_seg = len(resampfile)
count_seg = 0
for item_resamp in os.listdir(resampath):
    current_resamp = os.path.basename(item_resamp)
    if current_resamp == '.DS_Store':
        fullpath = os.path.join(resampath,current_resamp)
        os.remove(fullpath)

# %%
# feature for deep learning (3D): img

resampath = '/Users/eo-jin/Documents/research/1_MM/Segmentation_UNet/T1NORM/TEST/'
# resampath = '/Users/hwang/Documents/research/2_Prostate/Unet/nT2/Tz_resamp/train/'

resampfile = os.listdir(resampath)
resampfile.sort()
num_img = len(resampfile)

first = sitk.ReadImage(os.path.join(resampath,resampfile[0]))
feature = sitk.GetArrayFromImage(first)
feature_temp = feature.transpose(1,2,0)
feature_reshape = feature_temp.reshape(feature_temp.shape[0], feature_temp.shape[1], feature_temp.shape[2], 1)

num = 1

for n in os.listdir(resampath):

    i = sitk.ReadImage(os.path.join(resampath,resampfile[num]))
    j = sitk.GetArrayFromImage(i)
    j_temp = j.transpose(1,2,0)
    j_reshape = j_temp.reshape(j_temp.shape[0], j_temp.shape[1], j_temp.shape[2], 1)

    feature_reshape = np.concatenate([feature_reshape,j_reshape], axis = 3)
    
feature_reshape = feature_reshape[:,:,:,0:50]

# %%
# feature for deep learning (3D): mask 

resampath = '/Users/eo-jin/Documents/research/1_MM/Segmentation_UNet/ROI_RAD/TEST/'
# resampath = '/Users/hwang/Documents/research/2_Prostate/Unet/nT2/Tz_resamp/train/'

resampfile = os.listdir(resampath)
resampfile.sort()
num_img = len(resampfile)

first = sitk.ReadImage(os.path.join(resampath,resampfile[0]))
mask = sitk.GetArrayFromImage(first)
mask_temp = mask.transpose(1,2,0)
mask_reshape = mask_temp.reshape(mask_temp.shape[0], mask_temp.shape[1], mask_temp.shape[2], 1)

num = 1

for n in os.listdir(resampath):

    i = sitk.ReadImage(os.path.join(resampath,resampfile[num]))
    j = sitk.GetArrayFromImage(i)
    j_temp = j.transpose(1,2,0)
    j_reshape = j_temp.reshape(j_temp.shape[0], j_temp.shape[1], j_temp.shape[2], 1)

    mask_reshape = np.concatenate([feature_reshape,j_reshape], axis = 3)
    
mask_reshape = mask_reshape[:,:,:,0:50]

# %%
x_val = feature_reshape
y_val = mask_reshape

# %%
# augmentation by rotating 

import random

from scipy import ndimage


@tf.function
def rotate(volume):
    """Rotate the volume by a few degrees"""

    def scipy_rotate(volume):
        # define some rotation angles
        angles = [-20, -10, -5, 5, 10, 20]
        # pick angles at random
        angle = random.choice(angles)
        # rotate volume
        volume = ndimage.rotate(volume, angle, reshape=False)
        volume[volume < 0] = 0
        volume[volume > 1] = 1
        return volume

    augmented_volume = tf.numpy_function(scipy_rotate, [volume], tf.float32)
    return augmented_volume


def train_preprocessing(volume, label):
    """Process training data by rotating and adding a channel."""
    # Rotate volume
    volume = rotate(volume)
    volume = tf.expand_dims(volume, axis=3)
    return volume, label


def validation_preprocessing(volume, label):
    """Process validation data by only adding a channel."""
    volume = tf.expand_dims(volume, axis=3)
    return volume, label

# %%
train_loader = tf.data.Dataset.from_tensor_slices((x_train, y_train))
validation_loader = tf.data.Dataset.from_tensor_slices((x_val, y_val))

batch_size = 2
# Augment the on the fly during training.
train_dataset = (
    train_loader.shuffle(len(x_train))
    .map(train_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)
# Only rescale.
validation_dataset = (
    validation_loader.shuffle(len(x_val))
    .map(validation_preprocessing)
    .batch(batch_size)
    .prefetch(2)
)

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
x = tf.placeholder(shape=[None, 2], dtype=tf.float32)

# %%
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()

with tf.Session() as sess:
  x = tf.placeholder( tf.float32, [None, 784] )

# %%
import tensorflow as tf
x = tf.placeholder(shape=[None, 2], dtype=tf.float32)

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
x = tf.placeholder(shape=[None, 2], dtype=tf.float32)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-b5d605c8fcf4> in <module>
#       1 import tensorflow as tf
# ----> 2 x = tf.placeholder(shape=[None, 2], dtype=tf.float32)
#       3
#       4 import tensorflow.compat.v1 as tf
#       5 tf.disable_v2_behavior()
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'

# %%
model = unet3d((528,528,32,1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-cfaba1c3925a> in <module>
# ----> 1 model = unet3d((528,528,32,1))
#
# ~/Documents/3D-unet-keras-Brats2019-master/train/network.py in unet3d(vol_size)
#      37
#      38 def unet3d(vol_size):
# ---> 39     inputs = Input(shape=vol_size)
#      40     depth = configTrain.DEPTH
#      41     filters = []
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_layer.py in Input(shape, batch_shape, name, dtype, sparse, tensor)
#     173     if not dtype:
#     174         dtype = K.floatx()
# --> 175     input_layer = InputLayer(batch_input_shape=batch_shape,
#     176                              name=name, dtype=dtype,
#     177                              sparse=sparse,
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/engine/input_layer.py in __init__(self, input_shape, batch_size, batch_input_shape, dtype, input_tensor, sparse, name)
#      82         if input_tensor is None:
#      83             self.is_placeholder = True
# ---> 84             input_tensor = K.placeholder(shape=batch_input_shape,
#      85                                          dtype=dtype,
#      86                                          sparse=self.sparse,
#
# /opt/anaconda3/lib/python3.8/site-packages/keras/backend/tensorflow_backend.py in placeholder(shape, ndim, dtype, sparse, name)
#     516         dtype = floatx()
#     517     if not shape:
# --> 518         if ndim:
#     519             shape = tuple([None for _ in range(ndim)])
#     520     if sparse:
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'

# %%
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 528, 528, 32 0
# __________________________________________________________________________________________________
# conv3d_110 (Conv3D)             (None, 528, 528, 32, 448         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 528, 528, 32, 64          conv3d_110[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_110 (LeakyReLU)     (None, 528, 528, 32, 0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv3d_111 (Conv3D)             (None, 528, 528, 32, 6928        leaky_re_lu_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 528, 528, 32, 64          conv3d_111[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_111 (LeakyReLU)     (None, 528, 528, 32, 0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv3d_112 (Conv3D)             (None, 528, 528, 32, 6928        leaky_re_lu_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 528, 528, 32, 64          conv3d_112[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_112 (LeakyReLU)     (None, 528, 528, 32, 0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 528, 528, 32, 0           leaky_re_lu_110[0][0]
#                                                                  leaky_re_lu_112[0][0]
# __________________________________________________________________________________________________
# conv3d_113 (Conv3D)             (None, 264, 264, 16, 13856       add_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 264, 264, 16, 128         conv3d_113[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_113 (LeakyReLU)     (None, 264, 264, 16, 0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv3d_114 (Conv3D)             (None, 264, 264, 16, 27680       leaky_re_lu_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 264, 264, 16, 128         conv3d_114[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_114 (LeakyReLU)     (None, 264, 264, 16, 0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv3d_115 (Conv3D)             (None, 264, 264, 16, 27680       leaky_re_lu_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 264, 264, 16, 128         conv3d_115[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_115 (LeakyReLU)     (None, 264, 264, 16, 0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 264, 264, 16, 0           leaky_re_lu_113[0][0]
#                                                                  leaky_re_lu_115[0][0]
# __________________________________________________________________________________________________
# conv3d_116 (Conv3D)             (None, 132, 132, 8,  55360       add_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 132, 132, 8,  256         conv3d_116[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_116 (LeakyReLU)     (None, 132, 132, 8,  0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv3d_117 (Conv3D)             (None, 132, 132, 8,  110656      leaky_re_lu_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 132, 132, 8,  256         conv3d_117[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_117 (LeakyReLU)     (None, 132, 132, 8,  0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv3d_118 (Conv3D)             (None, 132, 132, 8,  110656      leaky_re_lu_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 132, 132, 8,  256         conv3d_118[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_118 (LeakyReLU)     (None, 132, 132, 8,  0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 132, 132, 8,  0           leaky_re_lu_116[0][0]
#                                                                  leaky_re_lu_118[0][0]
# __________________________________________________________________________________________________
# conv3d_119 (Conv3D)             (None, 66, 66, 4, 12 221312      add_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 66, 66, 4, 12 512         conv3d_119[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_119 (LeakyReLU)     (None, 66, 66, 4, 12 0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv3d_120 (Conv3D)             (None, 66, 66, 4, 12 442496      leaky_re_lu_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 66, 66, 4, 12 512         conv3d_120[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_120 (LeakyReLU)     (None, 66, 66, 4, 12 0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv3d_121 (Conv3D)             (None, 66, 66, 4, 12 442496      leaky_re_lu_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 66, 66, 4, 12 512         conv3d_121[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_121 (LeakyReLU)     (None, 66, 66, 4, 12 0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 66, 66, 4, 12 0           leaky_re_lu_119[0][0]
#                                                                  leaky_re_lu_121[0][0]
# __________________________________________________________________________________________________
# conv3d_122 (Conv3D)             (None, 33, 33, 2, 25 884992      add_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 33, 33, 2, 25 1024        conv3d_122[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_122 (LeakyReLU)     (None, 33, 33, 2, 25 0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv3d_123 (Conv3D)             (None, 33, 33, 2, 25 1769728     leaky_re_lu_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 33, 33, 2, 25 1024        conv3d_123[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_123 (LeakyReLU)     (None, 33, 33, 2, 25 0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv3d_124 (Conv3D)             (None, 33, 33, 2, 25 1769728     leaky_re_lu_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 33, 33, 2, 25 1024        conv3d_124[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_124 (LeakyReLU)     (None, 33, 33, 2, 25 0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 33, 33, 2, 25 0           leaky_re_lu_122[0][0]
#                                                                  leaky_re_lu_124[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_15 (UpSampling3D) (None, 66, 66, 4, 25 0           add_33[0][0]
# __________________________________________________________________________________________________
# conv3d_125 (Conv3D)             (None, 66, 66, 4, 12 884864      up_sampling3d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 66, 66, 4, 12 512         conv3d_125[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_125 (LeakyReLU)     (None, 66, 66, 4, 12 0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 66, 66, 4, 25 0           leaky_re_lu_125[0][0]
#                                                                  add_32[0][0]
# __________________________________________________________________________________________________
# conv3d_126 (Conv3D)             (None, 66, 66, 4, 12 884864      concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 66, 66, 4, 12 512         conv3d_126[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_126 (LeakyReLU)     (None, 66, 66, 4, 12 0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv3d_127 (Conv3D)             (None, 66, 66, 4, 12 442496      leaky_re_lu_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 66, 66, 4, 12 512         conv3d_127[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_127 (LeakyReLU)     (None, 66, 66, 4, 12 0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_16 (UpSampling3D) (None, 132, 132, 8,  0           leaky_re_lu_127[0][0]
# __________________________________________________________________________________________________
# conv3d_128 (Conv3D)             (None, 132, 132, 8,  221248      up_sampling3d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 132, 132, 8,  256         conv3d_128[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_128 (LeakyReLU)     (None, 132, 132, 8,  0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 132, 132, 8,  0           leaky_re_lu_128[0][0]
#                                                                  add_31[0][0]
# __________________________________________________________________________________________________
# conv3d_129 (Conv3D)             (None, 132, 132, 8,  221248      concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 132, 132, 8,  256         conv3d_129[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_129 (LeakyReLU)     (None, 132, 132, 8,  0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv3d_130 (Conv3D)             (None, 132, 132, 8,  110656      leaky_re_lu_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 132, 132, 8,  256         conv3d_130[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_130 (LeakyReLU)     (None, 132, 132, 8,  0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_18 (UpSampling3D) (None, 264, 264, 16, 0           leaky_re_lu_130[0][0]
# __________________________________________________________________________________________________
# conv3d_132 (Conv3D)             (None, 264, 264, 16, 55328       up_sampling3d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 264, 264, 16, 128         conv3d_132[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_132 (LeakyReLU)     (None, 264, 264, 16, 0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 264, 264, 16, 0           leaky_re_lu_132[0][0]
#                                                                  add_30[0][0]
# __________________________________________________________________________________________________
# conv3d_133 (Conv3D)             (None, 264, 264, 16, 55328       concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 264, 264, 16, 128         conv3d_133[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_133 (LeakyReLU)     (None, 264, 264, 16, 0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv3d_134 (Conv3D)             (None, 264, 264, 16, 27680       leaky_re_lu_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 264, 264, 16, 128         conv3d_134[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_134 (LeakyReLU)     (None, 264, 264, 16, 0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_20 (UpSampling3D) (None, 528, 528, 32, 0           leaky_re_lu_134[0][0]
# __________________________________________________________________________________________________
# conv3d_136 (Conv3D)             (None, 528, 528, 32, 13840       up_sampling3d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 528, 528, 32, 64          conv3d_136[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_136 (LeakyReLU)     (None, 528, 528, 32, 0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 528, 528, 32, 0           leaky_re_lu_136[0][0]
#                                                                  add_29[0][0]
# __________________________________________________________________________________________________
# conv3d_137 (Conv3D)             (None, 528, 528, 32, 13840       concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 528, 528, 32, 64          conv3d_137[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_137 (LeakyReLU)     (None, 528, 528, 32, 0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv3d_138 (Conv3D)             (None, 528, 528, 32, 6928        leaky_re_lu_137[0][0]
# __________________________________________________________________________________________________
# conv3d_131 (Conv3D)             (None, 132, 132, 8,  6916        leaky_re_lu_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 528, 528, 32, 64          conv3d_138[0][0]
# __________________________________________________________________________________________________
# conv3d_135 (Conv3D)             (None, 264, 264, 16, 3460        leaky_re_lu_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 132, 132, 8,  16          conv3d_131[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_138 (LeakyReLU)     (None, 528, 528, 32, 0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 264, 264, 16, 16          conv3d_135[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_131 (LeakyReLU)     (None, 132, 132, 8,  0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv3d_139 (Conv3D)             (None, 528, 528, 32, 1732        leaky_re_lu_138[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_135 (LeakyReLU)     (None, 264, 264, 16, 0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_17 (UpSampling3D) (None, 264, 264, 16, 0           leaky_re_lu_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 528, 528, 32, 16          conv3d_139[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 264, 264, 16, 0           leaky_re_lu_135[0][0]
#                                                                  up_sampling3d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_139 (LeakyReLU)     (None, 528, 528, 32, 0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_19 (UpSampling3D) (None, 528, 528, 32, 0           add_34[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 528, 528, 32, 0           leaky_re_lu_139[0][0]
#                                                                  up_sampling3d_19[0][0]
# __________________________________________________________________________________________________
# conv3d_140 (Conv3D)             (None, 528, 528, 32, 436         add_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 528, 528, 32, 16          conv3d_140[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_140 (LeakyReLU)     (None, 528, 528, 32, 0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# softmax (Activation)            (None, 528, 528, 32, 0           leaky_re_lu_140[0][0]
# ==================================================================================================
# Total params: 8,850,704
# Trainable params: 8,846,256
# Non-trainable params: 4,448
# __________________________________________________________________________________________________

# %%
callbacks_list = call(
         weight_path = configTrain.best_model_save_path, 
         monitor = configTrain.monitor , 
         mode = configTrain.mode, 
         reduce_lr_p = configTrain.reduce_lr_p, 
         early_p = configTrain.early_p, 
         log_csv_path = configTrain.log_csv_path,
         min_lr = configTrain.min_lr,
         factor = 0.5,
         min_delta = 0.0001,
         cooldown = 2,
         verbose = 1)
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
model.compile(
    optimizer=Adam(lr = configTrain.lr),
    loss=sm.losses.bce_jaccard_loss,
    metrics=[sm.metrics.iou_score],
)

loss_history = [model.fit_generator(
                        aug_gen, 
                        steps_per_epoch = 50, 
                        epochs = 10, 
                        validation_data = (valid_x, valid_y),
                        callbacks = callbacks_list,
                        workers = 1 
                                  )]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-1322d83c535a> in <module>
# ----> 1 import segmentation_models as sm
#       2
#       3 model.compile(
#       4     optimizer=Adam(lr = configTrain.lr),
#       5     loss=sm.losses.bce_jaccard_loss,
#
# ModuleNotFoundError: No module named 'segmentation_models'
